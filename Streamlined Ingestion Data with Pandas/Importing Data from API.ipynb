# %% [markdown]
# # JSON
#
#
# 1. Record Orientation
#
# ![image.png](attachment:image.png)
#
# 2. Column Orientation
#
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd

# %%
pop_in_shelters = pd.read_json("dhs_daily_report.json")

pop_in_shelters.head()
# Out:
#    adult_families_in_shelter  adults_in_families_with_children_in_shelter  \
# 0                       1796                                        14607
# 1                       1803                                        14622
# 2                       1802                                        14611
# 3                       1801                                        14650
# 4                       1804                                        14694
#
#    children_in_families_with_children_in_shelter           date_of_census  \
# 0                                          21314  2013-08-21T00:00:00.000
# 1                                          21324  2013-08-22T00:00:00.000
# 2                                          21291  2013-08-23T00:00:00.000
# 3                                          21343  2013-08-24T00:00:00.000
# 4                                          21400  2013-08-25T00:00:00.000
#
#    families_with_children_in_shelter  \
# ...

# %%
pop_in_shelters.describe()
# Out:
#        adult_families_in_shelter  adults_in_families_with_children_in_shelter  \
# count                1000.000000                                  1000.000000
# mean                 2074.955000                                 16487.932000
# std                   148.020238                                   848.363772
# min                  1796.000000                                 14607.000000
# 25%                  1906.000000                                 15831.500000
# 50%                  2129.000000                                 16836.000000
# 75%                  2172.250000                                 17118.250000
# max                  2356.000000                                 17733.000000
#
#        children_in_families_with_children_in_shelter  \
# count                                    1000.000000
# mean                                    23273.873000
# std                                       926.243984
# ...

# %%
#this is how to read another form of json

try:
    # Load the JSON with orient specified
    df = pd.read_json("dhs_report_reformatted.json",
                      orient = 'split')
    
    # Plot total population in shelters over time
    df["date_of_census"] = pd.to_datetime(df["date_of_census"])
    df.plot(x="date_of_census", 
            y="total_individuals_in_shelter")
    plt.show()
    
except ValueError:
    print("pandas could not parse the JSON.")
# Out:
# pandas could not parse the JSON.

# %% [markdown]
# # API

# %%
import requests
import pandas as pd

# %%
# SET HEADER
header = {"Authorization":'Bearer mhmt6jn3SFPVC1u6pfwgHWQvsa1wmWvCpKRtFGRYlo4mzA14SisQiDjyygsGMV2Dm7tEsuwdC4TYSA0Ai_GQTjKf9d5s5XLSNfQqdg1oy7jcBBh1i7iQUZBujdA_XHYx'}

#SET URL
api_url = "https://api.yelp.com/v3/businesses/search"

#SET PARAMS
params = {'term': 'cafe', 'location': 'NYC'}

# %%
response = requests.get(api_url,   
                        params=params,           
                        headers=header)

data = response.json()
print(data)
# Out:
# {'error': {'code': 'UNAUTHORIZED_ACCESS_TOKEN', 'description': 'The access token provided is not currently able to query this endpoint.'}}

# %%
cafe = pd.DataFrame(data['code'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cafe = pd.DataFrame(data['code'])
#
# KeyError: 'code'

# %% [markdown]
# # Nested JSON

# %%
phil = pd.read_json("raw_nyc_phil.json")

phil.head()
# Out:
#                                             programs
# 0  {'season': '1842-43', 'orchestra': 'New York P...
# 1  {'season': '1842-43', 'orchestra': 'New York P...
# 2  {'season': '1842-43', 'orchestra': 'Musicians ...
# 3  {'season': '1842-43', 'orchestra': 'New York P...
# 4  {'season': '1843-44', 'orchestra': 'New York P...
